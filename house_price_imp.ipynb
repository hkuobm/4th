# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.shape
# Out:
# (1460, 81)

# %%
test.shape
# Out:
# (1459, 80)

# %%
miss = train.isnull().sum()[train.isnull().sum() != 0]
miss
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
data = pd.concat((train.iloc[:,1:80], test.loc[:,'MSSubClass':'SaleCondition']))

# %%
train_1 = data.drop(['Alley','FireplaceQu','PoolQC', 'Fence', 'MiscFeature'], axis = 1)
train_1.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          60       RL         65.0     8450   Pave      Reg         Lvl
# 1          20       RL         80.0     9600   Pave      Reg         Lvl
# 2          60       RL         68.0    11250   Pave      IR1         Lvl
# 3          70       RL         60.0     9550   Pave      IR1         Lvl
# 4          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope      ...      OpenPorchSF EnclosedPorch  \
# 0    AllPub    Inside       Gtl      ...               61             0
# 1    AllPub       FR2       Gtl      ...                0             0
# 2    AllPub    Inside       Gtl      ...               42             0
# 3    AllPub    Corner       Gtl      ...               35           272
# 4    AllPub       FR2       Gtl      ...               84             0
#
#   3SsnPorch ScreenPorch PoolArea  MiscVal  MoSold  YrSold  SaleType  \
# ...

# %%
train_1.isnull().sum()[train_1.isnull().sum() != 0]
# Out:
# MSZoning          4
# LotFrontage     486
# Utilities         2
# Exterior1st       1
# Exterior2nd       1
# MasVnrType       24
# MasVnrArea       23
# BsmtQual         81
# BsmtCond         82
# BsmtExposure     82
# BsmtFinType1     79
# BsmtFinSF1        1
# BsmtFinType2     80
# BsmtFinSF2        1
# BsmtUnfSF         1
# TotalBsmtSF       1
# Electrical        1
# BsmtFullBath      2
# BsmtHalfBath      2
# KitchenQual       1
# Functional        2
# GarageType      157
# GarageYrBlt     159
# GarageFinish    159
# GarageCars        1
# GarageArea        1
# GarageQual      159
# GarageCond      159
# SaleType          1
# dtype: int64

# %%
train_1['CentralAir'].head()
# Out:
# 0    Y
# 1    Y
# 2    Y
# 3    Y
# 4    Y
# Name: CentralAir, dtype: object

# %%
air_mapping = {'Y': 1, 'N':0}

# %%
train_1['CentralAir'] = train_1['CentralAir'].map(air_mapping)
train_1['CentralAir'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: CentralAir, dtype: int64

# %%
train_1['ExterQual'].head()
# Out:
# 0    Gd
# 1    TA
# 2    Gd
# 3    TA
# 4    Gd
# Name: ExterQual, dtype: object

# %%
qual_mapping = {'Ex':4, 'Gd':3, 'TA':2, 'Fa':1, 'Po':0}

# %%
train_1['ExterQual'] = train_1['ExterQual'].map(qual_mapping)
train_1['ExterCond'] = train_1['ExterCond'].map(qual_mapping)

# %%
qual_mapping_2 =  {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1, 'No':0}

# %%
train_1['BsmtCond'] = train_1['BsmtCond'].map(qual_mapping_2)
train_1['BsmtQual'] = train_1['BsmtQual'].map(qual_mapping_2)

# %%
train_1['BsmtCond'] = train_1.fillna(train_1['BsmtCond'].median())

# %%
train_1['BsmtQual'] = train_1.fillna(train_1['BsmtQual'].median())

# %%
qual_mapping_3 = {'Gd':4, 'Av':3, 'Mn':2, 'No':1, 'NA':0}

# %%
train_1['BsmtExposure'] = train_1['BsmtExposure'].map(qual_mapping_3
                                                     )

# %%
qual_mapping_4 = {'GLQ':6, 'ALQ':5, 'BLQ':4, 'Rec':3, 'LwQ':2, 'Unf':1, 'NA':0}

# %%
train_1['BsmtFinType1'] = train_1['BsmtFinType1'].map(qual_mapping_4)
train_1['BsmtFinType2'] = train_1['BsmtFinType2'].map(qual_mapping_4)

# %%
train_1['BsmtFinType1'] = train_1.fillna(train_1['BsmtFinType1'].median())
train_1['BsmtFinType2'] = train_1.fillna(train_1['BsmtFinType2'].median())

# %%
train_1['HeatingQC'] = train_1['HeatingQC'].map(qual_mapping)

# %%
train_1['KitchenQual'] = train_1['KitchenQual'].map(qual_mapping)

# %%
garage_mapping = {'Fin':3, 'RFn':2, 'Unf':1, 'NA':0}

# %%
train_1['GarageFinish'] = train_1['GarageFinish'].map(garage_mapping)

# %%
train_1['GarageFinish'] = train_1.fillna(train_1['GarageFinish'].median())
train_1['GarageYrBlt'] = train_1.fillna(train_1['GarageYrBlt'].median())

# %%
train_1['GarageQual'] = train_1['GarageQual'].map(qual_mapping)
train_1['GarageCond'] = train_1['GarageCond'].map(qual_mapping)

# %%
train_1['GarageQual'] = train_1.fillna(train_1['GarageQual'].median())
train_1['GarageCond'] = train_1.fillna(train_1['GarageCond'].median())

# %%
train_1.isnull().sum()
# Out:
# MSSubClass         0
# MSZoning           4
# LotFrontage      486
# LotArea            0
# Street             0
# LotShape           0
# LandContour        0
# Utilities          2
# LotConfig          0
# LandSlope          0
# Neighborhood       0
# Condition1         0
# Condition2         0
# BldgType           0
# HouseStyle         0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# RoofStyle          0
# RoofMatl           0
# Exterior1st        1
# Exterior2nd        1
# MasVnrType        24
# MasVnrArea        23
# ExterQual          0
# ExterCond          0
# Foundation         0
# BsmtQual           0
# BsmtCond           0
#                 ...
# GrLivArea          0
# BsmtFullBath       2
# BsmtHalfBath       2
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# KitchenQual        1
# TotRmsAbvGrd       0
# Functional         2
# Fireplaces         0
# GarageType       157
# ...

# %%
train_1.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          60       RL         65.0     8450   Pave      Reg         Lvl
# 1          20       RL         80.0     9600   Pave      Reg         Lvl
# 2          60       RL         68.0    11250   Pave      IR1         Lvl
# 3          70       RL         60.0     9550   Pave      IR1         Lvl
# 4          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope      ...      OpenPorchSF EnclosedPorch  \
# 0    AllPub    Inside       Gtl      ...               61             0
# 1    AllPub       FR2       Gtl      ...                0             0
# 2    AllPub    Inside       Gtl      ...               42             0
# 3    AllPub    Corner       Gtl      ...               35           272
# 4    AllPub       FR2       Gtl      ...               84             0
#
#   3SsnPorch ScreenPorch PoolArea  MiscVal  MoSold  YrSold  SaleType  \
# ...

# %%
shape_mapping = {'Reg':3, 'IR1':2, 'IR2':1, 'IR3':0}

# %%
train_1['LotShape'] = train_1['LotShape'].map(shape_mapping)

# %%
uti_mapping = {'AllPub':3, 'NoSewr':2, 'NoSewa':1, 'ELO':0}

# %%
train['Utilities'] = train['Utilities'].map(uti_mapping)

# %%
numeric_feats = train_1.dtypes[train_1.dtypes != "object"].index

# %%
X = train_1[numeric_feats]
X.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  LotShape  OverallQual  OverallCond  \
# 0          60         65.0     8450         3            7            5
# 1          20         80.0     9600         3            6            8
# 2          60         68.0    11250         2            7            5
# 3          70         60.0     9550         2            7            5
# 4          60         84.0    14260         2            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ExterQual   ...    GarageArea  \
# 0       2003          2003       196.0          3   ...         548.0
# 1       1976          1976         0.0          2   ...         460.0
# 2       2001          2002       162.0          3   ...         608.0
# 3       1915          1970         0.0          2   ...         642.0
# 4       2000          2000       350.0          3   ...         836.0
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# ...

# %%
X.isnull().sum()[X.isnull().sum() != 0]
# Out:
# LotFrontage     486
# MasVnrArea       23
# BsmtExposure     82
# BsmtFinSF1        1
# BsmtFinSF2        1
# BsmtUnfSF         1
# TotalBsmtSF       1
# BsmtFullBath      2
# BsmtHalfBath      2
# KitchenQual       1
# GarageCars        1
# GarageArea        1
# dtype: int64

# %%
X_1 = X.drop(['LotFrontage', 'MasVnrArea', 'BsmtExposure'], axis = 1)
X_1
# Out:
#       MSSubClass  LotArea  LotShape  OverallQual  OverallCond  YearBuilt  \
# 0             60     8450         3            7            5       2003
# 1             20     9600         3            6            8       1976
# 2             60    11250         2            7            5       2001
# 3             70     9550         2            7            5       1915
# 4             60    14260         2            8            5       2000
# 5             50    14115         2            5            5       1993
# 6             20    10084         3            8            5       2004
# 7             60    10382         2            7            6       1973
# 8             50     6120         3            7            5       1931
# 9            190     7420         3            5            6       1939
# 10            20    11200         3            5            5       1965
# 11            60    11924         2            9            5       2005
# ...

# %%
X_1 = X_1.fillna(X_1.median())

# %%
y = train['SalePrice']

# %%
X_train = X_1[:train.shape[0]]
X_test = X_1[train.shape[0]:]

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (1460, 39)
# (1459, 39)

# %%
df = pd.concat([X_train, y], axis = 1)

# %%
df.head()
# Out:
#    MSSubClass  LotArea  LotShape  OverallQual  OverallCond  YearBuilt  \
# 0          60     8450         3            7            5       2003
# 1          20     9600         3            6            8       1976
# 2          60    11250         2            7            5       2001
# 3          70     9550         2            7            5       1915
# 4          60    14260         2            8            5       2000
#
#    YearRemodAdd  ExterQual  ExterCond  BsmtFinSF1    ...      WoodDeckSF  \
# 0          2003          3          2       706.0    ...               0
# 1          1976          2          2       978.0    ...             298
# 2          2002          3          2       486.0    ...               0
# 3          1970          2          2       216.0    ...               0
# 4          2000          3          2       655.0    ...             192
#
#    OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# ...

# %%
import seaborn as sns
df.corr()
# Out:
#                MSSubClass   LotArea  LotShape  OverallQual  OverallCond  \
# MSSubClass       1.000000 -0.139781  0.115361     0.032628    -0.059316
# LotArea         -0.139781  1.000000 -0.315484     0.105806    -0.005636
# LotShape         0.115361 -0.315484  1.000000    -0.198994     0.033747
# OverallQual      0.032628  0.105806 -0.198994     1.000000    -0.091932
# OverallCond     -0.059316 -0.005636  0.033747    -0.091932     1.000000
# YearBuilt        0.027850  0.014228 -0.229365     0.572323    -0.375983
# YearRemodAdd     0.040581  0.013788 -0.175488     0.550684     0.073741
# ExterQual        0.016178  0.055570 -0.188668     0.726278    -0.138942
# ExterCond       -0.064686  0.014732 -0.014073     0.013953     0.389163
# BsmtFinSF1      -0.069836  0.214103 -0.157718     0.239666    -0.046231
# BsmtFinSF2      -0.065649  0.111170 -0.060419    -0.059119     0.040229
# BsmtUnfSF       -0.140759 -0.002618 -0.014179     0.308159    -0.136841
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(random_state=0, n_estimators=100)
rfr.fit(X_train, y)
prediction = rfr.predict(X_test)
prediction
# Out:
# array([127640.  , 156254.  , 171543.23, ..., 155746.84, 113044.55,
#        220674.41])

# %%
print('train: %.3f' % rfr.score(X_train, y))
# Out:
# train: 0.982

# %%
Id = np.array(test['Id']).astype(int)
solution = pd.DataFrame(prediction, Id, columns = ['SalePrice'])
solution.to_csv('house_price_imp', index_label = ['Id'])

# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train_ans = train["Survived"]
train_ans.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
train = train.drop("Survived", axis = 1)
train.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
all_data = pd.concat([train, test])
all_data.isnull().sum()
# Out:
# PassengerId       0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
sex_map = {"male": 0, "female": 1}
all_data["Sex"] = all_data["Sex"].map(sex_map)
all_data["Sex"].head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Sex, dtype: int64

# %%
"""all_data["Age"] = all_data["Age"].fillna(all_data["Age"].mean())
all_data.isnull().sum()"""
# Out:
# 'all_data["Age"] = all_data["Age"].fillna(all_data["Age"].mean())\nall_data.isnull().sum()'

# %%
all_data["Fare"] = all_data["Fare"].fillna(all_data["Fare"].mean())

# %%
port_map = {"S":0, "C":1, "Q":2}
all_data["Embarked"] = all_data["Embarked"].map(port_map)
all_data["Embarked"] = all_data["Embarked"].fillna(all_data["Embarked"].mean())
all_data.isnull().sum()
# Out:
# PassengerId       0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# dtype: int64

# %%
all_data.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#    Sex   Age  SibSp  Parch            Ticket     Fare Cabin  Embarked
# 0    0  22.0      1      0         A/5 21171   7.2500   NaN       0.0
# 1    1  38.0      1      0          PC 17599  71.2833   C85       1.0
# 2    1  26.0      0      0  STON/O2. 3101282   7.9250   NaN       0.0
# 3    1  35.0      1      0            113803  53.1000  C123       0.0
# 4    0  35.0      0      0            373450   8.0500   NaN       0.0

# %%
len(all_data.index)
# Out:
# 1309

# %%
all_data = all_data.drop("Cabin", axis = 1)
all_data.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %%
all_data.loc[:,["Age"]].max()
# Out:
# Age    80.0
# dtype: float64

# %%
all_data.loc[:,["Age"]].min()
# Out:
# Age    0.17
# dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
all_data.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#    Sex   Age  SibSp  Parch            Ticket     Fare  Embarked
# 0    0  22.0      1      0         A/5 21171   7.2500       0.0
# 1    1  38.0      1      0          PC 17599  71.2833       1.0
# 2    1  26.0      0      0  STON/O2. 3101282   7.9250       0.0
# 3    1  35.0      1      0            113803  53.1000       0.0
# 4    0  35.0      0      0            373450   8.0500       0.0

# %%
all_data = pd.concat([all_data, all_data["Name"].str.split(",", expand = True)], axis = 1).drop("Name", axis = 1)
all_data.head()
# Out:
#    PassengerId  Pclass  Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0            1       3    0  22.0      1      0         A/5 21171   7.2500
# 1            2       1    1  38.0      1      0          PC 17599  71.2833
# 2            3       3    1  26.0      0      0  STON/O2. 3101282   7.9250
# 3            4       1    1  35.0      1      0            113803  53.1000
# 4            5       3    0  35.0      0      0            373450   8.0500
#
#    Embarked          0                                            1
# 0       0.0     Braund                              Mr. Owen Harris
# 1       1.0    Cumings   Mrs. John Bradley (Florence Briggs Thayer)
# 2       0.0  Heikkinen                                  Miss. Laina
# 3       0.0   Futrelle           Mrs. Jacques Heath (Lily May Peel)
# 4       0.0      Allen                            Mr. William Henry

# %%
all_data = all_data.drop(0, axis = 1)
all_data = all_data.rename(columns = {1 : "Name"})
all_data = pd.concat([all_data, all_data["Name"].str.split(".", expand = True)], axis = 1).drop("Name", axis = 1)
all_data.head()
# Out:
#    PassengerId  Pclass  Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0            1       3    0  22.0      1      0         A/5 21171   7.2500
# 1            2       1    1  38.0      1      0          PC 17599  71.2833
# 2            3       3    1  26.0      0      0  STON/O2. 3101282   7.9250
# 3            4       1    1  35.0      1      0            113803  53.1000
# 4            5       3    0  35.0      0      0            373450   8.0500
#
#    Embarked      0                                       1     2
# 0       0.0     Mr                             Owen Harris  None
# 1       1.0    Mrs   John Bradley (Florence Briggs Thayer)  None
# 2       0.0   Miss                                   Laina  None
# 3       0.0    Mrs           Jacques Heath (Lily May Peel)  None
# 4       0.0     Mr                           William Henry  None

# %%
all_data = all_data.drop([1,2], axis = 1)
all_data.head()
# Out:
#    PassengerId  Pclass  Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0            1       3    0  22.0      1      0         A/5 21171   7.2500
# 1            2       1    1  38.0      1      0          PC 17599  71.2833
# 2            3       3    1  26.0      0      0  STON/O2. 3101282   7.9250
# 3            4       1    1  35.0      1      0            113803  53.1000
# 4            5       3    0  35.0      0      0            373450   8.0500
#
#    Embarked      0
# 0       0.0     Mr
# 1       1.0    Mrs
# 2       0.0   Miss
# 3       0.0    Mrs
# 4       0.0     Mr

# %%
all_data = all_data.rename(columns = {0:"Name"})
all_data_1 = all_data.dropna(subset = ["Age"])
all_data_1.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# Name           0
# dtype: int64

# %%
df_1 = pd.DataFrame(all_data.groupby("Name")["PassengerId"].count())
df_1
# Out:
#                PassengerId
# Name
#  Capt                    1
#  Col                     4
#  Don                     1
#  Dona                    1
#  Dr                      8
#  Jonkheer                1
#  Lady                    1
#  Major                   2
#  Master                 61
#  Miss                  260
#  Mlle                    2
#  Mme                     1
#  Mr                    757
#  Mrs                   197
#  Ms                      2
#  Rev                     8
#  Sir                     1
#  the Countess            1

# %%
df_2 = pd.DataFrame(all_data.groupby("Name")["Age"].sum())
df_2
# Out:
#                     Age
# Name
#  Capt             70.00
#  Col             216.00
#  Don              40.00
#  Dona             39.00
#  Dr              305.00
#  Jonkheer         38.00
#  Lady             48.00
#  Major            97.00
#  Master          290.58
#  Miss           4572.59
#  Mlle             48.00
#  Mme              24.00
#  Mr            18738.50
#  Mrs            6289.00
#  Ms               28.00
#  Rev             330.00
#  Sir              49.00
#  the Countess     33.00

# %%
df_3 = pd.concat([df_1, df_2], axis = 1)
df_3["mean"] = df_3["Age"] / df_3["PassengerId"]
df_3
# Out:
#                PassengerId       Age       mean
# Name
#  Capt                    1     70.00  70.000000
#  Col                     4    216.00  54.000000
#  Don                     1     40.00  40.000000
#  Dona                    1     39.00  39.000000
#  Dr                      8    305.00  38.125000
#  Jonkheer                1     38.00  38.000000
#  Lady                    1     48.00  48.000000
#  Major                   2     97.00  48.500000
#  Master                 61    290.58   4.763607
#  Miss                  260   4572.59  17.586885
#  Mlle                    2     48.00  24.000000
#  Mme                     1     24.00  24.000000
#  Mr                    757  18738.50  24.753633
#  Mrs                   197   6289.00  31.923858
#  Ms                      2     28.00  14.000000
#  Rev                     8    330.00  41.250000
#  Sir                     1     49.00  49.000000
#  the Countess            1     33.00  33.000000

# %%
dic = {"Capt":70, "Col":54, "Don":40, "Dona":39, "Dr":38.125, "Jonkheer":38, "Lady":48, "Major":48.5, "Master":4.764
       , "Miss":17.587, "Mlle":24, "Mme":24, "Mr":24.75, "Mrs":31.92, "Ms":14, "Rev":41, "Sir":49, "the Countess":33}

# %%
miss = all_data[all_data.isnull().any(axis = 1)]
miss.head()
# Out:
#     PassengerId  Pclass  Sex  Age  SibSp  Parch  Ticket     Fare  Embarked  \
# 5             6       3    0  NaN      0      0  330877   8.4583       2.0
# 17           18       2    0  NaN      0      0  244373  13.0000       0.0
# 19           20       3    1  NaN      0      0    2649   7.2250       1.0
# 26           27       3    0  NaN      0      0    2631   7.2250       1.0
# 28           29       3    1  NaN      0      0  330959   7.8792       2.0
#
#      Name
# 5      Mr
# 17     Mr
# 19    Mrs
# 26     Mr
# 28   Miss

# %%
dic
# Out:
# {'Capt': 70,
#  'Col': 54,
#  'Don': 40,
#  'Dona': 39,
#  'Dr': 38.125,
#  'Jonkheer': 38,
#  'Lady': 48,
#  'Major': 48.5,
#  'Master': 4.764,
#  'Miss': 17.587,
#  'Mlle': 24,
#  'Mme': 24,
#  'Mr': 24.75,
#  'Mrs': 31.92,
#  'Ms': 14,
#  'Rev': 41,
#  'Sir': 49,
#  'the Countess': 33}

# %%
miss.groupby("Name")["PassengerId"].count()
# Out:
# Name
#  Dr          1
#  Master      8
#  Miss       50
#  Mr        176
#  Mrs        27
#  Ms          1
# Name: PassengerId, dtype: int64

# %%
dic_2 = {" Dr":38.125, " Master": 4.764, " Miss": 17.587, " Mr": 24.75, " Mrs":31.92, " Miss":14}

# %%
miss_name = pd.DataFrame(miss["Name"])
miss_name.head()
# Out:
#      Name
# 5      Mr
# 17     Mr
# 19    Mrs
# 26     Mr
# 28   Miss

# %%
miss_name["Name"] = miss_name["Name"].map(dic_2)
miss_name.head()
# Out:
#      Name
# 5   24.75
# 17  24.75
# 19  31.92
# 26  24.75
# 28  14.00

# %%
miss = miss.drop("Name", axis = 1)
miss.head()
# Out:
#     PassengerId  Pclass  Sex  Age  SibSp  Parch  Ticket     Fare  Embarked
# 5             6       3    0  NaN      0      0  330877   8.4583       2.0
# 17           18       2    0  NaN      0      0  244373  13.0000       0.0
# 19           20       3    1  NaN      0      0    2649   7.2250       1.0
# 26           27       3    0  NaN      0      0    2631   7.2250       1.0
# 28           29       3    1  NaN      0      0  330959   7.8792       2.0

# %%
miss = pd.concat([miss, miss_name], axis = 1)
miss.head()
# Out:
#     PassengerId  Pclass  Sex  Age  SibSp  Parch  Ticket     Fare  Embarked  \
# 5             6       3    0  NaN      0      0  330877   8.4583       2.0
# 17           18       2    0  NaN      0      0  244373  13.0000       0.0
# 19           20       3    1  NaN      0      0    2649   7.2250       1.0
# 26           27       3    0  NaN      0      0    2631   7.2250       1.0
# 28           29       3    1  NaN      0      0  330959   7.8792       2.0
#
#      Name
# 5   24.75
# 17  24.75
# 19  31.92
# 26  24.75
# 28  14.00

# %%
miss = miss.drop("Age", axis = 1)
miss = miss.rename(columns = {"Name":"Age"})
miss.head()
# Out:
#     PassengerId  Pclass  Sex  SibSp  Parch  Ticket     Fare  Embarked    Age
# 5             6       3    0      0      0  330877   8.4583       2.0  24.75
# 17           18       2    0      0      0  244373  13.0000       0.0  24.75
# 19           20       3    1      0      0    2649   7.2250       1.0  31.92
# 26           27       3    0      0      0    2631   7.2250       1.0  24.75
# 28           29       3    1      0      0  330959   7.8792       2.0  14.00

# %%
all_data_1 = all_data_1.drop("Name", axis = 1)
all_data_1.head()
# Out:
#    PassengerId  Pclass  Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0            1       3    0  22.0      1      0         A/5 21171   7.2500
# 1            2       1    1  38.0      1      0          PC 17599  71.2833
# 2            3       3    1  26.0      0      0  STON/O2. 3101282   7.9250
# 3            4       1    1  35.0      1      0            113803  53.1000
# 4            5       3    0  35.0      0      0            373450   8.0500
#
#    Embarked
# 0       0.0
# 1       1.0
# 2       0.0
# 3       0.0
# 4       0.0

# %%
all_data_2 = pd.concat([all_data_1, miss], axis = 0)
all_data_2.head()
# Out:
#     Age  Embarked     Fare  Parch  PassengerId  Pclass  Sex  SibSp  \
# 0  22.0       0.0   7.2500      0            1       3    0      1
# 1  38.0       1.0  71.2833      0            2       1    1      1
# 2  26.0       0.0   7.9250      0            3       3    1      0
# 3  35.0       0.0  53.1000      0            4       1    1      1
# 4  35.0       0.0   8.0500      0            5       3    0      0
#
#              Ticket
# 0         A/5 21171
# 1          PC 17599
# 2  STON/O2. 3101282
# 3            113803
# 4            373450

# %%
all_data_2 = all_data_2.drop("Ticket", axis = 1)

# %%
all_data_2 = all_data_2.sort_values("PassengerId")
all_data_2.head(6)
# Out:
#      Age  Embarked     Fare  Parch  PassengerId  Pclass  Sex  SibSp
# 0  22.00       0.0   7.2500      0            1       3    0      1
# 1  38.00       1.0  71.2833      0            2       1    1      1
# 2  26.00       0.0   7.9250      0            3       3    1      0
# 3  35.00       0.0  53.1000      0            4       1    1      1
# 4  35.00       0.0   8.0500      0            5       3    0      0
# 5  24.75       2.0   8.4583      0            6       3    0      0

# %%
df_train = all_data_2[:891]

# %%
df_train.tail()
# Out:
#       Age  Embarked   Fare  Parch  PassengerId  Pclass  Sex  SibSp
# 886  27.0       0.0  13.00      0          887       2    0      0
# 887  19.0       0.0  30.00      0          888       1    1      0
# 888  14.0       0.0  23.45      2          889       3    1      1
# 889  26.0       1.0  30.00      0          890       1    0      0
# 890  32.0       2.0   7.75      0          891       3    0      0

# %%
df_test = all_data_2[891:]
df_test.isnull().sum()
# Out:
# Age            1
# Embarked       0
# Fare           0
# Parch          0
# PassengerId    0
# Pclass         0
# Sex            0
# SibSp          0
# dtype: int64

# %%
train_answer = pd.DataFrame(train_ans, columns = ["Survived"])

# %%
train_answer.head()
# Out:
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
from sklearn.ensemble import RandomForestClassifier
rfc_1 = RandomForestClassifier(random_state=0, n_estimators=10)
rfc_1.fit(df_train, train_answer)
# Out:
# C:\Users\hkuob\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
error = df_test[df_test.isnull().any(axis = 1)]
error
# Out:
#     Age  Embarked  Fare  Parch  PassengerId  Pclass  Sex  SibSp
# 88  NaN       2.0  7.75      0          980       3    1      0

# %%
test.iloc[[88]]
# Out:
#     PassengerId  Pclass                     Name     Sex  Age  SibSp  Parch  \
# 88          980       3  O'Donoghue, Ms. Bridget  female  NaN      0      0
#
#     Ticket  Fare Cabin Embarked
# 88  364856  7.75   NaN        Q

# %%
df_test = df_test.fillna(14)

# %%
df_test.isnull().sum()
# Out:
# Age            0
# Embarked       0
# Fare           0
# Parch          0
# PassengerId    0
# Pclass         0
# Sex            0
# SibSp          0
# dtype: int64

# %%
prediction = rfc_1.predict(df_test)
prediction.shape
# Out:
# (418,)

# %%
PassengerId = np.array(test['PassengerId']).astype(int)
solution = pd.DataFrame(prediction, PassengerId, columns=['Survived'])
solution.to_csv('titanic_ans.csv', index_label = ['PassengerId'])
